# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from flask) (1.8.2)
# Requirement already satisfied: colorama in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.5)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (2.16.2)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (70.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.4.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.1.2)

# %%
# !pip install setuptools tensorflow
# Out:
# Requirement already satisfied: setuptools in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (70.2.0)
# Requirement already satisfied: tensorflow in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (2.16.2)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.32.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.4.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.1.2)

# %%
# !pip install distlib
# Out:
# Requirement already satisfied: distlib in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (0.3.8)

# %%
# !python -m ensurepip --upgrade
# Out:
# Looking in links: c:\Users\DEEPIK~1\AppData\Local\Temp\tmpwxdzq82n
# Requirement already satisfied: pip in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (24.1.1)

# %%
# !pip install distutils
# Out:
# ERROR: Could not find a version that satisfies the requirement distutils (from versions: none)
# ERROR: No matching distribution found for distutils

# %%
# !pip install setuptools
# Out:
# Requirement already satisfied: setuptools in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (70.2.0)

# %%
import os
main_data_dir = r'C:\Users\DEEPIKA M\OneDrive\Desktop\dsatm\Segmented Medicinal Leaf Images'
batch_size = 32
num_classes = len(os.listdir(main_data_dir))
epochs = 10

# %%
# Create label mapping based on subdirectory names
label_mapping = {i: label for i, label in enumerate(sorted(os.listdir(main_data_dir)))}

# %%
label_mapping
# Out:
# {0: 'Alpinia Galanga (Rasna)',
#  1: 'Amaranthus Viridis (Arive-Dantu)',
#  2: 'Artocarpus Heterophyllus (Jackfruit)',
#  3: 'Azadirachta Indica (Neem)',
#  4: 'Basella Alba (Basale)',
#  5: 'Brassica Juncea (Indian Mustard)',
#  6: 'Carissa Carandas (Karanda)',
#  7: 'Citrus Limon (Lemon)',
#  8: 'Ficus Auriculata (Roxburgh fig)',
#  9: 'Ficus Religiosa (Peepal Tree)',
#  10: 'Hibiscus Rosa-sinensis',
#  11: 'Jasminum (Jasmine)',
#  12: 'Mangifera Indica (Mango)',
#  13: 'Mentha(mint)',
#  14: 'Moringa Oleifera (Drumstick)',
#  15: 'Muntingia Calabura (Jamaica Cherry-Gasagase)',
#  16: 'Murraya Koenigii (Curry)',
#  17: 'Nerium Oleander (Oleander)',
#  18: 'Nyctanthes Arbor-tristis (Parijata)',
#  19: 'Ocimum Tenuiflorum (Tulsi)',
#  20: 'Piper Betle (Betel)',
#  21: 'Plectranthus Amboinicus (Mexican Mint)',
#  22: 'Pongamia Pinnata (Indian Beech)',
#  23: 'Psidium Guajava (Guava)',
#  24: 'Punica Granatum (Pomegranate)',
#  25: 'Santalum Album (Sandalwood)',
#  26: 'Syzygium Cumini (Jamun)',
#  27: 'Syzygium Jambos (Rose Apple)',
#  28: 'Tabernaemontana Divaricata (Crape Jasmine)',
#  29: 'Trigonella Foenum-graecum (Fenugreek)'}

# %%
image_path = r'C:\Users\DEEPIKA M\OneDrive\Desktop\dsatm\Segmented Medicinal Leaf Images\Alpinia Galanga (Rasna)\AG-S-001.jpg'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('on')  # Turn off axis labels and ticks
plt.show()

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# Load the trained model
model = tf.keras.models.load_model('plant_identification_model.h5')

# Load and preprocess the image
def preprocess_image(image_path):
    image = load_img(image_path, target_size=(224, 224))
    image_array = img_to_array(image)
    image_array = np.expand_dims(image_array, axis=0)
    preprocessed_image = preprocess_input(image_array)
    return preprocessed_image

# Perform prediction
def predict_plant(image_path, label_mapping):
    preprocessed_image = preprocess_image(image_path)
    predictions = model.predict(preprocessed_image)
    
    # Map model's numeric predictions to labels
    predicted_label_index = np.argmax(predictions)
    predicted_label = label_mapping[predicted_label_index]
    confidence = predictions[0][predicted_label_index]
    
    return predicted_label, confidence

# Provide the path to the image you want to classify
predicted_label, confidence = predict_plant(image_path, label_mapping)

# Print the prediction
print(f"Predicted Label: {predicted_label}")
print(f"Confidence: {confidence:.2f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Label: Syzygium Jambos (Rose Apple)
# Confidence: 0.68

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (2.16.2)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (70.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.4.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.1.2)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (3.4.1)
# Requirement already satisfied: absl-py in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\deepika m\onedrive\desktop\herbscan-main\.venv\lib\site-packages (1.26.4)
